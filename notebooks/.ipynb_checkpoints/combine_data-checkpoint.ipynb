# %%
import os
import pandas as pd
pd.set_option("display.max_columns", 100)
from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorOphysProjectCache
import brain_observatory_utilities.datasets.optical_physiology.data_formatting as ophys_formatting
import brain_observatory_utilities.utilities.general_utilities as utilities
import pickle
from glob import glob

# %%
datafolder = "D:\\neuromatch2024\\datasets\\project\\Allen\\temp\\"      ### Please rename this appropriately
cache = VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=datafolder)
# Out:
# C:\Users\bosem\miniconda3\envs\allenSDK\lib\site-packages\allensdk\brain_observatory\behavior\behavior_project_cache\behavior_project_cache.py:135: UpdatedStimulusPresentationTableWarning:
# 	As of AllenSDK version 2.16.0, the latest Visual Behavior Ophys data has been significantly updated from previous releases. Specifically the user will need to update all processing of the stimulus_presentations tables. These tables now include multiple stimulus types delineated by the columns `stimulus_block` and `stimulus_block_name`.
#
# The data that was available in previous releases are stored in the block name containing 'change_detection' and can be accessed in the pandas table by using:
# 	`stimulus_presentations[stimulus_presentations.stimulus_block_name.str.contains('change_detection')]`
#   warnings.warn(

# %%
session_table = cache.get_ophys_session_table().reset_index()
experiment_table = cache.get_ophys_experiment_table().reset_index()
behavior_table = cache.get_behavior_session_table().reset_index()

# %%
session_table.head()
# Out:
#    ophys_session_id  behavior_session_id  \
# 0         951410079            951520319
# 1         952430817            952554548
# 2         954954402            953982960
# 3         955775716            956010809
# 4         957020350            957032492
#
#                                   ophys_container_id mouse_id indicator  \
# 0  [1018028339, 1018028342, 1018028345, 101802835...   457841   GCaMP6f
# 1   [1018028339, 1018028345, 1018028354, 1018028357]   457841   GCaMP6f
# 2  [1018028339, 1018028342, 1018028345, 101802835...   457841   GCaMP6f
# 3               [1018028339, 1018028342, 1018028345]   457841   GCaMP6f
# 4  [1018028339, 1018028342, 1018028345, 101802835...   457841   GCaMP6f
#
#                                    full_genotype     driver_line  \
# 0  Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  [Sst-IRES-Cre]
# 1  Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  [Sst-IRES-Cre]
# 2  Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  [Sst-IRES-Cre]
# ...

# %%
experiment_table.head()
# Out:
#    ophys_experiment_id  behavior_session_id  ophys_session_id  \
# 0            951980471            951520319         951410079
# 1            951980473            951520319         951410079
# 2            951980475            951520319         951410079
# 3            951980479            951520319         951410079
# 4            951980481            951520319         951410079
#
#    ophys_container_id mouse_id indicator  \
# 0          1018028342   457841   GCaMP6f
# 1          1018028345   457841   GCaMP6f
# 2          1018028339   457841   GCaMP6f
# 3          1018028354   457841   GCaMP6f
# 4          1018028357   457841   GCaMP6f
#
#                                    full_genotype     driver_line  \
# 0  Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  [Sst-IRES-Cre]
# 1  Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  [Sst-IRES-Cre]
# 2  Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  [Sst-IRES-Cre]
# 3  Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt  [Sst-IRES-Cre]
# ...

# %%
session_table[session_table.ophys_session_id.isin(
    [ 916650386,  920695792,  923705570, 1048363441, 1050597678,
       1051107431, 1076239955, 1077657878, 1078596841, 1080522184,
       1081652280, 1082487233]
)][["ophys_session_id", "mouse_id", "cre_line"]].to_csv("..\\datafiles\\creline.csv", index=False)

# %%
all_files = glob(f"{datafolder}behavior_ophys_experiments\\*.nwb")
exp_ids = [f.split(".")[0] for f in all_files]
exp_ids = [int(f.split("_")[-1]) for f in exp_ids]

# %%
test_ids = [
    951520319,
    957032492,
    1041977344,
    873695653,
    824894721,
    907053876,
    894083470,
    820124540,
    1066967257,
    884808160
]

# %%
experiment_table[experiment_table.ophys_experiment_id.isin(exp_ids)].head()

# %%
experiment_table[experiment_table.ophys_experiment_id.isin(exp_ids)].project_code.unique()

# %%
experiment_table[experiment_table.ophys_experiment_id.isin(exp_ids)].mouse_id.unique()

# %%
experiment_table[experiment_table.ophys_experiment_id.isin(exp_ids)].experience_level.unique()

# %%
gdf = experiment_table[experiment_table.ophys_experiment_id.isin(exp_ids)].reset_index().groupby(
    ["project_code", "mouse_id", "experience_level"]
).agg(
    image_set = ("image_set", "unique"), 
    exp_id = ("ophys_experiment_id", "unique"), 
    session_id = ("ophys_session_id", "unique")
).reset_index()

mouse_ids_to_keep = ['453990', '523922', '544965', '546605']

gdf = gdf[gdf.mouse_id.isin(mouse_ids_to_keep)].reset_index(drop=True)
gdf["session_id"] = [x[0] for x in gdf["session_id"]]
gdf

# %%
gdf.to_csv("Session_desc.csv", index=False)

# %%
gdf.exp_id[0], gdf.session_id[0]

# %%
for _, row in gdf.iterrows():
    exps = row["exp_id"]
    for exp in exps:
        if exp not in exp_ids:
            print(row["session_id"], exp)
        else:
            print("Present")

# %% [markdown]
# ## First thing to extract : neural data

# %%
def extract_data(ophys_session_id, ophys_experiment_ids):
    experiments = {}
    for ophys_experiment_id in ophys_experiment_ids:
        experiments[ophys_experiment_id] = cache.get_behavior_ophys_experiment(ophys_experiment_id)

    neural_data = []
    for ophys_experiment_id in ophys_experiment_ids:
        this_experiment = experiments[ophys_experiment_id]
        this_experiment_neural_data = ophys_formatting.build_tidy_cell_df(this_experiment)
    
        # add some columns with metadata for the experiment
        metadata_keys = [
            "ophys_experiment_id",
            "ophys_session_id",
            "targeted_structure",
            "imaging_depth",
            "equipment_name",
            "cre_line",
            "mouse_id",
            "sex",
        ]
        for metadata_key in metadata_keys:
            this_experiment_neural_data[metadata_key] = this_experiment.metadata[
                metadata_key
            ]
    
        # append the data for this experiment to a list
        neural_data.append(this_experiment_neural_data)
    
    # concatate the list of dataframes into a single dataframe
    neural_data = pd.concat(neural_data)

    stimulus_table = this_experiment.stimulus_presentations.reset_index()

    trials = this_experiment.trials.reset_index() 

    licks = this_experiment.licks 

    rewards = this_experiment.rewards

    eyetracking = this_experiment.eye_tracking

    running = this_experiment.running_speed

    masterdict = {
        "neural_data" : neural_data,
        "stimulus_table" : stimulus_table,
        "trials" : trials,
        "licks" : licks,
        "rewards" : rewards,
        "eyetracking" : eyetracking,
        "running" : running
    }

    with open(f'{datafolder}combined_files\\masterfile_{ophys_session_id}.pickle', 'wb') as handle:
        pickle.dump(masterdict, handle)

# %%
for _, row in gdf.iterrows():
    ophys_session_id = row["session_id"]
    ophys_experiment_ids = row["exp_id"]
    extract_data(ophys_session_id, ophys_experiment_ids)
    print("Data saved")

# %% [markdown]
# ## You can read back the file as follows

# %%
# with open(f'{datafolder}masterfile_{ophys_session_id}.pickle', 'rb') as handle:
#     masterdict = pickle.load(handle)
# masterdict
